# %% [markdown]
# # Guided Capstone Step 3 Exploratory Data Analysis

# %% [markdown]
# This is the third step in the Data Science Method. We introduced this topic in the last subunit. With Data Wrangling out of the way we can progress to the Exploratory Data Analysis section. In this exercise, you will learn to build data profiles and plots, including relationship plot and data correlation plot. You will also implement k-means clustering, complete clusters, and update data frame as a CSV file. Let's get started!
#
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#   * Data Collection
#    * Data Organization
#   * Data Definition
#   * Data Cleaning
#
# 3.   **Exploratory Data Analysis**
#  * Build data profile tables and plots
#         - Outliers & Anomalies
#  * Explore data relationships
#  * Identification and creation of features
#
# 4.   Pre-processing and Training Data Development
#   * Create dummy or indicator features for categorical variables
#   * Standardize the magnitude of numeric features
#   * Split into testing and training datasets
#   * Apply scaler to the testing set
# 5.   Modeling
#   * Fit Models with Training Data Set
#   * Review Model Outcomes — Iterate over additional models as needed.
#   * Identify the Final Model
#
# 6.   Documentation
#   * Review the Results
#   * Present and share your findings - storytelling
#   * Finalize Code
#   * Finalize Documentation

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages as we did in step 2 and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

#load python packages

# %% [markdown]
# **<font color='teal'> If you need to change your path refer back to step 2 on how to do that. Then load the csv file you created in step 2, remember it should be saved inside your data subfolder and print the first five rows.</font>**

# %% [markdown]
# # Build data profile tables and plots

# %% [markdown]
# **<font color='teal'> Print out the summary stats table transposed to fit on the screen using the `describe()` function.</font>**

# %%
df = pd.read_csv('/home/vince/nstem/models/sb/gc/gc2/Step2/step2_out.csv')
df = df.drop(["Unnamed: 0"], axis=1)
df = df.dropna()
df.describe()
# Out:
#         summit_elev  vertical_drop    base_elev      trams  fastEight  \
# count     56.000000      56.000000    56.000000  56.000000       56.0
# mean    2910.928571     911.089286  1955.517857   0.071429        0.0
# std     2345.247007     695.925630  1965.278292   0.259870        0.0
# min      720.000000     175.000000   170.000000   0.000000        0.0
# 25%     1237.500000     372.500000   800.000000   0.000000        0.0
# 50%     2048.000000     637.500000  1108.500000   0.000000        0.0
# 75%     3471.750000    1162.500000  1853.250000   0.000000        0.0
# max    10677.000000    2537.000000  8600.000000   1.000000        0.0
#
#        fastSixes  fastQuads       quad     triple     double  ...  \
# count  56.000000  56.000000  56.000000  56.000000  56.000000  ...
# mean    0.089286   0.589286   1.035714   1.303571   1.767857  ...
# std     0.287736   1.074951   1.374631   1.476108   2.272292  ...
# min     0.000000   0.000000   0.000000   0.000000   0.000000  ...
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000  ...
# 50%     0.000000   0.000000   1.000000   1.000000   1.000000  ...
# 75%     0.000000   1.000000   2.000000   2.000000   3.000000  ...
# max     1.000000   4.000000   5.000000   7.000000  14.000000  ...
#
#        LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  \
# count      56.000000          56.000000       56.000000         56.000000
# mean        1.224401         347.500000      129.535714        111.889849
# std         0.894483         633.175805      125.274530         25.653423
# min         0.100000          15.000000       13.000000         42.000000
# 25%         0.500000          53.750000       49.250000         99.750000
# 50%         1.000000         102.500000       95.500000        114.551971
# 75%         1.500000         258.750000      152.500000        124.500000
# max         4.500000        3000.000000      600.000000        180.000000
#
#        yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  \
# count  56.000000        56.000000     56.000000     56.000000
# mean   53.833152       122.529159     52.629589     61.384643
# std    14.603044       111.666489     18.333461     17.764106
# min    12.000000        18.000000     17.000000     25.000000
# 25%    46.750000        50.000000     40.000000     46.500000
# 50%    55.500000        85.000000     49.500000     62.000000
# 75%    61.250000       161.750000     63.500000     75.250000
# max    83.000000       669.000000    105.000000    105.000000
#
#        projectedDaysOpen  NightSkiing_ac
# count          56.000000       56.000000
# mean          115.134465       97.285714
# std            26.594366      112.455682
# min            42.000000       12.000000
# 25%           100.000000       36.500000
# 50%           120.000000       68.000000
# 75%           122.250000      100.000000
# max           193.000000      600.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# **<font color='teal'> Histograms are an excellent way to review the range and density of values for each numeric features in your data set and build data profiles. Plot the histograms for all numeric features and adjust the bins size to 25.</font>**

# %%
df.plot(kind='hist', bins=25)

# %% [markdown]
# Look for similarities in the features that may indicate that they are duplicates or highly correlated features. Make a note of your findings and any other interesting insights you find about these numeric features.

# %% [markdown]
# **<font color='teal'> Okay, now you should be getting a sense for what the data look like. Let's create a barplot for the categorical features `Region` and `state` where the heights of the bars are the counts of each level in that variable. </font>**

# %% [markdown]
# **<font color='teal'>State Levels Plot</font>**

# %%
# Uncomment the following code to get your visualization started
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the states 
x = pd.DataFrame(df.state.value_counts())
print(x.isnull().sum())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.state into the list() function
values = list(x.state)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above.
sns.barplot(x=values, y=names, palette="RdBu_r")
# Out:
# state    0
# dtype: int64

# %% [markdown]
# **<font color='teal'>Region Levels Plot</font>**

# %%
# Now do the same for regions!

# %% [markdown]
# By reviewing the State and Regions counts plots you should notice that the Region feature is nearly identical to the state and therfore we can remove from the dataframe.**<font color='teal'> Remove the `Region` column using the drop function.</font>**

# %% [markdown]
# ## Anamolies & Outliers - Review boxplots

# %% [markdown]
# **<font color='teal'> Print boxplot for every column</font>**
#
# Hint: you'll see the methodology here in this article on Exploratory Data Analysis [here](nce-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %% [markdown]
# You need to create boxplots and  histograms to evaluate the data for potential outliers or data anomalies. Generally, outliers are defined as observations that differ significantly from the other values in the dataset or feature.
#
# Reviewing the distribution of values by column will help you  interpret this. Outliers are extreme values that fall far outside the mean and standard deviation of a set of observations. They  can mislead the training process in building machine learning models. Outliers may be real anomalies in the observations or artificial errors.
#
# One method for outlier analysis is extreme value analysis using a boxplot, which assumes a normal distribution. The figure below describes the components of a boxplot. Notice the outlier is the point outside the upper whisker end.
#
# ![](AnnotatedBoxplot.png)
# <font color='teal'>Follow these steps:
#
# 1. Create boxplots - earlier step
# 2. Apply outlier removal using the Interquartile range or replacement
# 3. Review how many observations were removed</font>
#
# Hint: Recall from your statistics prework that a common definition of an outlier is an observation lying more than (1.5 * the Interquartile range) above the third quartile, or more than just that much below the first quartile.

# %%
# Let's get the Interquartile range, or IQR. This is equal to Q3 - Q1. 
# First, let's use the quantile() method to get the first quartile, and store it in a variable called Q1.
# We'll want to plug 0.25 into the quantile method.
Q1 = df.quantile(0.25)

# Now get Q3 and store in a variable called Q3.
Q3 = df.quantile(0.75)

# Now get Q3 and store in a variable called Q3.
Q3 = df.quantile(0.75)

# Now calculate the IQR, storing it in a variable called IQR.
IQR = Q3 - Q1
# Make a variable call ed `dfno`, and assign it the value: df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)].
# This filters on our existing dataframe, picking out just those observations that are NOT outliers.
dfno=df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)]
# We now want to make a boxplot of this new dataframe dfno.
dfno.boxplot(grid=False, vert=False,fontsize=15, figsize=(12,15))

# %%
# Print the shapes of our dataframes df and dfno to compare the number of observations in each.

# %% [markdown]
# There are many ways to discover and remove outliers, and what counts as a sensible way of doing so depends on your problem, your methodology for solving that problem, and the nature of your data.
#
# Each method will have its merits and demerits. As we can see, in this instance, we've lost a great many observations!
#
# There is no hard and fast rule as to which outlier removal method is best in all cases, and you will have to exercise your good judgement in arriving at an appropriate method for your problem at hand. We will cover outlier removal in more depth in units 7 (Data Wrangling) and 10 (Statistics for Exploratory Data Analysis) of the course.

# %% [markdown]
# There are many possible response variables you could have identified in Step 1 of this guided capstone. However, for the rest of this guided capstone project, we will focus on increasing revenue by increasing the lift ticket prices and the number of days the resort is open per year. In this case, we need to investigate the expected lift ticket price for Big Mountain based on all the other given resort characteristics. In addition, we want to predict the number of days the resort will be open each season.

# %% [markdown]
# <font color='teal'>**Review the `AdultWeekday`,`AdultWeekend` response variable distributions**</font>

# %%
# Make a histogram of the 'AdultWeekday' column of the dfno dataframe. 
# You'll want to call hist() on that column
dfno.hist(['AdultWeekday'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2950e3de90>]],
#       dtype=object)

# %%
# Do the same but with the AdultWeekend column
dfno.hist(['AdultWeekend'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f29511abc90>]],
#       dtype=object)

# %% [markdown]
# <font color='teal'>**Review the `daysOpenLastYear`,`projecteDaysOpen` response variable distributions**</font>

# %%
# Do the same as above! You got this :)
dfno.hist(['daysOpenLastYear'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f29510cf1d0>]],
#       dtype=object)

# %%
dfno.hist(['projectedDaysOpen'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2951036510>]],
#       dtype=object)

# %% [markdown]
# # Explore data relationships

# %% [markdown]
# <font color='teal'>**Create pairplots or what is commonly referred to as biplots**</font>
#
# Hint: pairplots are covered in this article on EDA [here](https://medium.com/@aiden.dataminer/the-data-science-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %% [markdown]
# # Identification and creation of features

# %% [markdown]
# <font color='teal'>**Create a Pearson correlation heatmap**</font>

# %%
#Calculate the correlation coefficients
corr = df.corr()
#plot it in the next line
corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# /home/vince/miniconda3/envs/sb/lib/python3.7/site-packages/matplotlib/colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col5 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col8 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col10 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col18 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col19 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col20 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col22 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col23 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow0_col24 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col2 {
#             background-color:  #f39577;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col3 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col4 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col5 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col6 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col7 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col8 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col9 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col10 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col11 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col12 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col13 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col14 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col15 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col16 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col17 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col18 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col19 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col20 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col21 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col22 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col23 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow1_col24 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow2_col0 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow2_col1 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow2_col3 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow2_col4 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow2_col5 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow2_col6 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow2_col7 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow2_col8 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_68089ac8_9c85_11ea_8953_f3fa9206daebrow2_col9 {
#             background-color:  #a6c4fe;

# %% [markdown]
# When reviewing the Pearson correlation coefficient heatmap, you can see substantial differences in the correlations compared to the response variable(s) as well as in the features when compared to each other. The heatmap helps identify features that suffer from multi-collinearity.

# %% [markdown]
# <font color='teal'>**Use the correlation matrix displayed in the heatmap to select and remove collinear features. Remember to exclude the response variable(s) from the matrix to ensure they are retained in your final model development dataset. Then select those features that are more than 95% correlated for removal.**</font>
#
# Step 1: Create a correlation matrix that excludes your response variables.
#
# Step 2: Select the upper triangle of the correlation matrix. This is because a correlation matrix actually contains the same information, twice over!
#
# Step 3: Find the index of feature columns with a correlation greater than 0.95.

# %%
# Step 1. Call the variable corr_matrix
corr_matrix = dfno.drop(['AdultWeekday','AdultWeekend','daysOpenLastYear','projectedDaysOpen'], axis=1).corr().abs()

# Step 2. Uncomment the following code to get the upper triangle of the correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Step 3. This code iterates through our columns and gets the index of any that have a correlation > 0.95
# Call the variable to_drop, get the columns of our 'upper' variable, make sure the threshold is 0.95.
to_drop = [column for column in upper.columns if any(upper[column] >0.95)]

# %%
# Let's see those features! 
print('Features selected to drop include:',to_drop)
# Out:
# Features selected to drop include: ['base_elev']

# %%
print('Reduced dataframe size: ',dfno.drop(dfno[to_drop], axis=1).shape)
# Out:
# Reduced dataframe size:  (174, 27)

# %%
# Now replace dfno by the result of dropping the columns in the to_drop variable from it
dfno = dfno.drop(dfno[to_drop], axis=1)

# %% [markdown]
# Now we address the feature creation piece of this step. We can create additional features through many methods such as: combining several features, grouping features into bins, or even by applying an unsupervised classification algorithm, such as k-means clustering and using the clusters as features in our model development dataset.
#
# Clustering essentially finds patterns in data when we don't know in advance what we're looking for. The K-means algorithm is one way of doing clustering. It puts our data into groups (or 'clusters') which can then become features for further analysis. What the k-means algorithm outputs, though, depends on the number of clusters we set out to have. We will use a method called 'Elbow plotting' to determine this number.
#
# We will cover clustering and k-means thoroughly in the Unsupervised Learning unit of this course, but for now, we'll use it for feature creation alone, which is an integral part of Exploratory Data Analysis. Don't worry if you don't understand the details just yet.

# %% [markdown]
# Run the next two cells below to create an Elbow plot. The Elbow plot is a diagnostic tool that helps us determine the number of clusters to include in our k-means clustering implementation.
#
# In this example, the error between clusters and within clusters is compared for a range of 1 to 11 clusters, and it appears the elbow is between two and four, therefore we set the parameter k = 3.

# %%
from sklearn.cluster import KMeans
x = dfno.drop(columns=['Name','state','Region'], axis =1).values
print(x)
# Out:
# [[2.00000000e+00 2.09000000e+03 2.94000000e+02 ... 3.40000000e+01
#   1.52000000e+02 3.00000000e+01]
#  [4.00000000e+00 1.11000000e+04 1.80000000e+03 ... 7.80000000e+01
#   1.04000000e+02 8.00000000e+01]
#  [5.00000000e+00 7.80000000e+03 6.00000000e+02 ... 4.70000000e+01
#   1.07000000e+02            nan]
#  ...
#  [3.27000000e+02 7.80800000e+03 1.57100000e+03 ... 5.90000000e+01
#   1.23000000e+02 1.10000000e+02]
#  [3.28000000e+02 9.66300000e+03 9.90000000e+02 ... 4.90000000e+01
#   1.20053004e+02            nan]
#  [3.29000000e+02 9.50000000e+03 1.10000000e+03 ... 4.90000000e+01
#   1.20053004e+02            nan]]

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(add_indicator=True)
from sklearn.compose import make_column_transformer
ct = make_column_transformer(
    (imp, ['TerrainParks', 'Runs', 'LongestRun_mi', 'SkiableTerrain_ac', 'Snow Making_ac',
           'daysOpenLastYear', 'yearsOpen', 'averageSnowfall', 'projectedDaysOpen']),
    remainder='passthrough')

from sklearn.pipeline import make_pipeline

Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i)
    pipe = make_pipeline(ct, kmeans)
    pipe.fit(x)
    Error.append(pipe.named_steps['kmeans'].inertia_)
    import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/envs/sb/lib/python3.7/site-packages/sklearn/utils/__init__.py in _get_column_indices(X, key)
#     442         try:
# --> 443             all_columns = list(X.columns)
#     444         except AttributeError:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-828fec78dcdb> in <module>
#      13     kmeans = KMeans(n_clusters = i)
#      14     pipe = make_pipeline(ct, kmeans)
# ---> 15     pipe.fit(x)
#      16     Error.append(pipe.named_steps['kmeans'].inertia_)
#      17     import matplotlib.pyplot as plt
#
# ~/miniconda3/envs/sb/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     348             This estimator
#     349         """
# --> 350         Xt, fit_params = self._fit(X, y, **fit_params)
#     351         with _print_elapsed_time('Pipeline',
#     352                                  self._log_message(len(self.steps) - 1)):
#
# ~/miniconda3/envs/sb/lib/python3.7/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     313                 message_clsname='Pipeline',
#     314                 message=self._log_message(step_idx),
# --> 315                 **fit_params_steps[name])
#     316             # Replace the transformer of the step with the fitted
#     317             # transformer. This is necessary when loading the transformer
#
# ~/miniconda3/envs/sb/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# ~/miniconda3/envs/sb/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     726     with _print_elapsed_time(message_clsname, message):
#     727         if hasattr(transformer, 'fit_transform'):
# --> 728             res = transformer.fit_transform(X, y, **fit_params)
#     729         else:
#     730             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~/miniconda3/envs/sb/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py in fit_transform(self, X, y)
#     514         self._validate_transformers()
#     515         self._validate_column_callables(X)
# --> 516         self._validate_remainder(X)
#     517
#     518         result = self._fit_transform(X, y, _fit_transform_one)
#
# ~/miniconda3/envs/sb/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py in _validate_remainder(self, X)
#     322         cols = []
#     323         for columns in self._columns:
# --> 324             cols.extend(_get_column_indices(X, columns))
#     325         remaining_idx = list(set(range(self._n_features)) - set(cols))
#     326         remaining_idx = sorted(remaining_idx) or None
#
# ~/miniconda3/envs/sb/lib/python3.7/site-packages/sklearn/utils/__init__.py in _get_column_indices(X, key)
#     443             all_columns = list(X.columns)
#     444         except AttributeError:
# --> 445             raise ValueError("Specifying the columns using strings is only "
#     446                              "supported for pandas DataFrames")
#     447         if isinstance(key, str):
#
# ValueError: Specifying the columns using strings is only supported for pandas DataFrames

# %% [markdown]
# <font color='teal'>**Fit the kmeans algorithm with the k parameter set to three and plot the results.**</font>

# %%
# This code will fit the k-means algorithm with our k parameter set to three, and plot the results. Cool, huh? 
kmeans3 = KMeans(n_clusters=3)
y_kmeans3 = kmeans3.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')

centers = kmeans3.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-140d31a8eb6a> in <module>
#       1 # This code will fit the k-means algorithm with our k parameter set to three, and plot the results. Cool, huh?
#       2 kmeans3 = KMeans(n_clusters=3)
# ----> 3 y_kmeans3 = kmeans3.fit_predict(x)
#       4 plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')
#       5
#
# ~/miniconda3/envs/sb/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py in fit_predict(self, X, y, sample_weight)
#    1006             Index of the cluster each sample belongs to.
#    1007         """
# -> 1008         return self.fit(X, sample_weight=sample_weight).labels_
#    1009
#    1010     def fit_transform(self, X, y=None, sample_weight=None):
#
# ~/miniconda3/envs/sb/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     857         order = "C" if self.copy_x else None
#     858         X = check_array(X, accept_sparse='csr', dtype=[np.float64, np.float32],
# --> 859                         order=order, copy=self.copy_x)
#     860         # verify that the number of samples given is larger than k
#     861         if _num_samples(X) < self.n_clusters:
#
# ~/miniconda3/envs/sb/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# ~/miniconda3/envs/sb/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# <font color='teal'>**Add the clusters to your dataframe as a new column to include in the next step and write the updated dataframe out as csv. Save the dataframe in the data folder and name it `step3_output.csv`.**</font>

# %%
# Make a new column in your dfno dataframe called 'clusters', and assign it the variable: y_kmeans3

# %%
# Write your dataframe to csv
